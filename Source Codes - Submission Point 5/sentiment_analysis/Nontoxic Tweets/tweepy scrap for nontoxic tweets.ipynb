# %%
import os
import tweepy as tw
import pandas as pd

# %%
#Add your credentials here
twitter_keys = {
        'consumer_key':        'DY6bpywglf35jBV9RLfe12Rly',
        'consumer_secret':     'YVHXvmWd1dr4HMY7kDPYlqv56wq3xBcokz9T6CzjYyIglJVSBL',
        'access_token_key':    '1331467933214621702-vTWiqTQCghYXjiS1ztfzEI4Rimjtmg',
        'access_token_secret': 'uqb6yVfV5QH3lTgqUtwTgQ4BHKJa1BUZCU6Hy3ucEwLuR'
    }

#Setup access to API
auth = tw.OAuthHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])

api = tw.API(auth,wait_on_rate_limit=True)

# %%
def extract_place(row):
    if row['associated_place']:
        return row['associated_place'].full_name
    else:
        return None
    
def extract_location(row):
    if row['user_location']:
        return row['user_location']
    else:
        return None

# %%
text_query = 'e OR a OR r OR i OR o -has:geo'
max_tweets = 10000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]
 
# Creation of dataframe from tweets_list
# Did not include column names to simplify code 
tweets_df = pd.DataFrame(tweets_list)

# %%
tweets_df = pd.DataFrame(tweets_list)
tweets_df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
                     'user_description','verified','associated_place','retweet_count']
tweets_df.head()
# Out:
#                                                 text   created_date_time  \
# 0  @katey_harvey If we're talking strictly Boyzon... 2021-02-15 19:00:56
# 1  This girl on tik tok is absolutely sobbing at ... 2021-02-15 19:00:56
# 2  @MsMikaylaMiles I would not need breakfast if ... 2021-02-15 19:00:56
# 3  RT @TrueBlueNude: #NudeMemeMonday – Harkening ... 2021-02-15 19:00:56
# 4  @varindersingh24 My best friend who died from ... 2021-02-15 19:00:56
#
#               tweet_id               username user_screen_name  \
# 0  1361390052786532363  Terry (Tony) Thatcher       deThatched
# 1  1361390052689858560                 leidy🌿  leidythetheydie
# 2  1361390052660674562                     AS       Salami1959
# 3  1361390052635512836                 Turpin  Turpin_Outdoors
# 4  1361390052593573890               Ann Else          MomElse
#
#               user_id  user_location  \
# 0  952517196579770369
# 1  814065060846784512
# 2            19663553
# 3  956482632572964864  United States
# 4           118076633  Waterford, MI
#
#                                     user_description  verified  \
# 0  Professional wrestler. Talented love maker. Su...     False
# 1            21| illegal | they/she| Venmo:leidy-m26     False
# 2                                                        False
# 3                                                        False
# 4  Love my four beautiful kids more than anything...     False
#
#   associated_place  retweet_count
# 0             None              0
# 1             None              0
# 2             None              0
# 3             None              8
# 4             None              0

# %%
tweets_df['associated_place'] = tweets_df.apply(extract_place,axis=1)
tweets_df['user_location'] = tweets_df.apply(extract_location,axis=1)
tweets_df.head(30)
# Out:
#                                                  text   created_date_time  \
# 0   @katey_harvey If we're talking strictly Boyzon... 2021-02-15 19:00:56
# 11  1361390052341911560           JohnThePro (Momoe Sawaki szn)
# 12  1361390052316745730                                      H🌙
# 13  1361390052249640960                           Charles AMOYA
# 14  1361390052228612101                                    𝒔𝒖𝒔𝒚
# 15  1361390052228534272                                       🌸
# 16  1361390052224434179                        Lawrence Schimel
# 17  1361390052220223498                                  Yamper
# 18  1361390052195074048                                    Paqu
# 19  1361390052178239488                            Max Santiago
# 20  1361390052178206721                                aimsters
# 21  1361390052174086148                          Toni-Ann Myers
# 22  1361390052165754882                          boujee hoodlum
# 23  1361390052157366278                                   Titan
# 24  1361390052157362181                      F U N C T I Ó N ❤️
# 25  1361390052148994048                      Nat⁷ ᥫ᭡sᴏʙᴏᴋ sᴏʙᴏᴋ
# 26  1361390052148973569                                  Jordan
# 27  1361390052140609543                                   Sammy
# 28  1361390052140580866                          CEO of chiCKEN
# 29  1361390052140539907  Juan Pablo S - Spanish Marketing Ninja
#
#    user_screen_name              user_id                  user_location  \
# 0        deThatched   952517196579770369                           None
# 1   leidythetheydie   814065060846784512                           None
# 2        Salami1959             19663553                           None
# 3   Turpin_Outdoors   956482632572964864                  United States
# 4           MomElse            118076633                  Waterford, MI
# 5     mangi_maubane  1252583384083304448                           PTA
# 6      JessicasuAKA   908322279087595525       Scotland, United Kingdom
# 7      PrayanKumar1  1221361727658283010                           None
# 8         SimonTaub           4466673192                           None
# 9        NyaMuriuki  1084450505219293185                           None
# 10        Flat_What           1307408959                           None
# 11      JohnThePro7  1026456143256858624                  Σέρρες, Ελλάς
# 12   goldenstylesx_            716791600           𝐌𝐚𝐧 𝐁𝐞𝐝𝐫𝐨𝐨𝐦She/her18
# 13          amoyace            338704827  Secret Place of the Most High
# 14   susypescatore_           2308476029               Napoli, Campania
# 15  chilelepaleleee   948853129231003648             Bandung, Indonesia
# 16  lawrenceschimel             22408955                  Madrid, Spain
# 17      LoverYamper  1244607516576808962             New Hampshire, USA
# 18  PaquInDeception           4082738789                           None
# 19  dudemanbro_317_   843712378915057665                       Brea, CA
# 20        Amyhamada             58705980                Los Angeles, CA
# 21     ToniAnnMyers           1626332144                 The Pizzle, FL
# 22          naebili  1092741638391246848                        Nigeria
# 23         Titan10M  1253721831984508930                           None
# 24   Function_Gully            230503727                           None
# 25       jikookmint   806605107328667652  Jimin's bellybutton ♡ she/her
# 26          ZemaaEU   958848886562541568                           None
# 27         Parximew   954685628838547456                Galway, Ireland
# 28      hnghchicken   892656860809003008                           None
# 29     juanpabloSP_            836773248                Sevilla, España
#
#                                      user_description  verified  \
# 0   Professional wrestler. Talented love maker. Su...     False
# 1             21| illegal | they/she| Venmo:leidy-m26     False
# 2                                                         False
# 3                                                         False
# 4   Love my four beautiful kids more than anything...     False
# 5                Where Words Fail Music Speaks🎶🎼🎹🎷🎺🎧🎶     False
# 6   Scot/Turk/27/Autistic/disabled/NB/queer/wc/Ren...     False
# 7                    CPF/Army/Blink/selenator/swiftie     False
# 8              Hallmark Channel | Pokemon GO | Somper     False
# 9                                 never that serious✨     False
# 10  26, Italian, she/her. Italiano / English / 日本語...     False
# 11  Male|🇬🇷|19|#StanSheyta|Anime Procrastinator|Ki...     False
# 12  𝐰𝐞 𝐟𝐨𝐮𝐧𝐝 𝐨𝐮𝐫𝐬𝐞𝐥𝐯𝐞𝐬 𝐢𝐧 𝐞𝐚𝐜𝐡 𝐨𝐭𝐡𝐞𝐫. 𝐵𝐿𝑀 𝙷𝚊𝚛𝚛𝚢|ℝ𝕠...     False
# 13  Proudly IJAW | Oil and Gas | Maritime | Chemic...     False
# 14                             turkish dizis addicted     False
# 15                                       fan account.     False
# 16  Bilingual (Spanish/English) poet & author & li...     False
# 17  16 years old, I like singing, painting, stop b...     False
# 18                                                        False
# 19  Umbra Mortis \nNo time for mental clutches the...     False
# 20                                                  ☼     False
# 21                    Navigating through the madness.     False
# 22                             I have nothing to say.     False
# 23                                         be a titan     False
# 24                                       Born Winner.     False
# 25       ᴶᵘⁿᵍᵏᵒᵒᵏ ᵗᶦⁿʸ 🌺 ɢʀᴀᴍᴍʏ ɴᴏᴍɪɴᴀᴛᴇᴅ ᴀʀᴛɪsᴛs ʙᴛs     False
# 26                                                        False
# 27  I love @Cxctys | Weeb Shit and Tetris™ | she/they     False
# 28  I'm just someone who got bored and made a Twit...     False
# 29  Hispanic & English market advocate.🇪🇸🇲🇽 Direct...     False
#
#    associated_place  retweet_count
# 0              None              0
# 1              None              0
# 2              None              0
# 3              None              8
# 4              None              0
# 5              None             44
# 6              None            745
# 7              None              0
# 8              None              0
# 9              None           5298
# 10             None              0
# 11             None              0
# 12             None              0
# 13             None              0
# 14             None           2876
# 15             None              1
# 16             None              2
# 17             None              0
# 18             None             11
# 19             None              0
# 20             None              0
# 21             None              0
# 22             None              0
# 23             None              0
# 24             None            270
# 25             None              0
# 26             None              0
# 27             None              0
# 28             None              0
# 29             None              0

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               10000 non-null  object
#  1   created_date_time  10000 non-null  datetime64[ns]
#  2   tweet_id           10000 non-null  object
#  3   username           10000 non-null  object
#  4   user_screen_name   10000 non-null  object
#  5   user_id            10000 non-null  object
#  6   user_location      6844 non-null   object
#  7   user_description   10000 non-null  object
#  8   verified           10000 non-null  bool
#  9   associated_place   104 non-null    object
#  10  retweet_count      10000 non-null  int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 478.6+ KB

# %%
tweets_df = tweets_df[tweets_df.user_location.notnull()]
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6844 entries, 3 to 9999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               6844 non-null   object
#  1   created_date_time  6844 non-null   datetime64[ns]
#  2   tweet_id           6844 non-null   object
#  3   username           6844 non-null   object
#  4   user_screen_name   6844 non-null   object
#  5   user_id            6844 non-null   object
#  6   user_location      6844 non-null   object
#  7   user_description   6844 non-null   object
#  8   verified           6844 non-null   bool
#  9   associated_place   98 non-null     object
#  10  retweet_count      6844 non-null   int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 381.0+ KB

# %%
tweets_df = tweets_df.sample(frac=1).reset_index(drop=True)

# %%
tweets_df.to_csv('random_tweets.csv',index = False)
