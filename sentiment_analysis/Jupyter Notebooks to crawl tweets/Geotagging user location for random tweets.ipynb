# %%
import os
import tweepy as tw
import pandas as pd
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv("random_tweets.csv")
df.head()
# Out:
#                                                 text    created_date_time  \
# 0  RT @TrumpWarRoom___: RT to wish a Happy Presid...  2021-02-15 19:00:53
# 1  RT @Rules_twt: If "uncomfortable" was a pictur...  2021-02-15 19:00:48
# 2  @ShaiDeLuca It can’t be an ethnoreligion for a...  2021-02-15 19:00:40
# 3  RT @_ixcato: I think he's neat. :) #criticalro...  2021-02-15 19:00:47
# 4  RT @Tomas_Verde: Who's the brave soul who is g...  2021-02-15 19:00:56
#
#               tweet_id             username user_screen_name  \
# 0  1361390039108907008           VaQuireboy       VaQuireboy
# 1  1361390020008038402       𝓐𝓷𝓪 𝓒𝓻𝓲𝓼𝓽𝓲𝓷𝓪 ✨      bemAtoaAqui
# 2  1361389986126254082      Comrade Mayoist      AnarchoMayo
# 3  1361390012466667520  Spectre’s Icy Touch   spectrealafete
# 4  1361390051448545280         Taylor Moats        idigmoats
#
#                user_id           user_location  \
# 0   742076049618538496           Virginia, USA
# 1  1182740439184658438         Moura, Portugal
# 2  1285070649568817152  Occupied Duwamish Land
# 3             40359764        Toronto, Ontario
# 4   836340324205199361   Whitemarsh Island, GA
#
#                                     user_description  verified  \
# 0  Family man, College educated, Independent, Vie...     False
# 1                            ♐️//#SimAosToiros// F 💓     False
# 2  The beatings will continue until morale improv...     False
# 3  Mostly just flailing about changelings... and ...     False
# 4                                                NaN     False
#
#   associated_place  retweet_count
# 0              NaN           2124
# 1              NaN            613
# 2              NaN              0
# 3              NaN            108
# 4              NaN             26

# %%
geolocator = Nominatim(user_agent="toxic_tweet_analyser")

from geopy.extra.rate_limiter import RateLimiter

geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
df['location'] = df['user_location'].apply(geocode)

df['user_location'] = df['location'].apply(lambda loc: str(loc.address) if loc else None)
df['user_geo'] = df['location'].apply(lambda loc: str(loc.point) if loc else None)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('United States',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=United+States&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=United+States&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=United+States&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('London, England',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('London, England',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter swallowed an error after 2 retries. Called with (*('London, England',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London%2C+England&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('he cow she ',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('he cow she ',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter swallowed an error after 2 retries. Called with (*('he cow she ',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=he+cow+she+&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Houston Medical Center, TX, US',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Houston+Medical+Center%2C+TX%2C+US&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Houston+Medical+Center%2C+TX%2C+US&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# ...
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=831+%7C+408&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=831+%7C+408&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=831+%7C+408&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Dublin fair city.',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Dublin+fair+city.&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Dublin+fair+city.&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Dublin+fair+city.&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('19',), **{}).
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 1002, in recv_into
#     return self.read(nbytes, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 865, in read
#     return self._sslobj.read(len, buffer)
#   File "c:\users\user\appdata\local\programs\python\python36-32\lib\ssl.py", line 625, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 337, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 796, in urlopen
#     **response_kw
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\urllib3\util\retry.py", line 573, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "d:\cz4034 - information retrieval\env\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)",))

# %%
df['user_geo'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 23  G, North Griffin Street, West End Historic Dis...
# 26        Mumbai, Mumbai Suburban, Maharashtra, India
# 27                                      United States
# 29                            New York, United States
# 31  Deep Woods, Goochland County, Virginia, 23067,...
# 33                                          Argentina
# 34                                      United States
# 35  Mar Vista, Los Angeles, Los Angeles County, Ca...
# 36                        België / Belgique / Belgien
# 38  Milwaukee, Milwaukee County, Wisconsin, United...
# 39  1, Vertland, Indianapolis, Indiana, United States
#
#                                      user_description  verified  \
# 0   Family man, College educated, Independent, Vie...     False
# 1                             ♐️//#SimAosToiros// F 💓     False
# 3   Mostly just flailing about changelings... and ...     False
# 4                                                 NaN     False
# 5   tiny girl pretending to do chemistry by day @H...     False
# 6                                          a believer     False
# 7   Dream Of Becoming A Professional Wrestler \nAn...     False
# 8   • Jambrish To You. Michigan Braider. TheHoneyE...     False
# 10  Adulte responsable en cours de construction, j...     False
# 11  God-Country-Family. #ProLife. #2A. Law & Order...     False
# 12  I am Suyash Raj. Web Entrepreneur, Keen Observ...     False
# 13  she/her\nrainbows, roller derby, ridiculousnes...     False
# 14                                  feliz. Only Atiny     False
# 15  Wear a mask. Old & grey but only slightly wise...     False
# 16  We want to empower you by sharing inspirationa...     False
# 17                                                NaN     False
# 18  College of Arts and Humanities at Georgia Sout...     False
# 19            Just your run of the mill third nipple.     False
# 21                                           orgasmic     False
# 23                                       Coming soon!     False
# 26  Madly and deeply crazy for deepveer🌍 Sadda Haq...     False
# 27  Jack of all Trades +V+🔥V+🔥V+\nMASTERVOFVUNIVER...     False
# 29  Doesn’t cost to smile & be civil ! | Hindu Bha...     False
# 31  🏈DC, S&CC,Head Wrestling Coach @ Stanhope Elmo...     False
# 33                     nunca supe que escribir acá, F     False
# 34  Look to ASSA ABLOY Entrance Systems US for hig...     False
# 35  reluctant activist.....hope we all survive and...     False
# 36  Curmudgeonly Irish expat; citizen of everywher...     False
# 38                                           Prolific     False
# 39  Currently an @IUPUIPH grad student, class of 2...     False
#
#    associated_place  retweet_count  \
# 0               NaN           2124
# 1               NaN            613
# 3               NaN            108
# 4               NaN             26
# 5               NaN              0
# 6               NaN           3967
# 7               NaN              0
# 8               NaN          11131
# 10              NaN          28968
# 11              NaN            939
# 12              NaN              0
# 13              NaN             11
# 14              NaN            336
# 15              NaN            271
# 16              NaN              0
# 17              NaN              6
# 18              NaN              2
# 19              NaN              0
# 21              NaN          13831
# 23              NaN              0
# 26              NaN              0
# 27     Georgia, USA              0
# 29              NaN            169
# 31              NaN              0
# 33              NaN           6367
# 34              NaN              0
# 35              NaN            133
# 36              NaN              0
# 38              NaN              3
# 39              NaN              5
#
#                                              location  \
# 0   (Virginia, United States, (37.1232245, -78.492...
# 1   (Moura, Beja, Baixo Alentejo, Alentejo, Portug...
# 3   (Toronto, Golden Horseshoe, Ontario, Canada, (...
# 4   (Whitemarsh Island, Chatham County, Georgia, 3...
# 5   (Cambridge, Middlesex County, Massachusetts, U...
# 6   (The Southern, East 5th Street, Skid Row, Down...
# 7   (山川坛, 南纬路南巷 (nánwěi lù nán xiàng), 西城区, 北京市, 1...
# 8   (The Beehive, Beehive Lane, Hall Grove, Welwyn...
# 10                   (France, (46.603354, 1.8883335))
# 11  (Orlando, Orange County, Florida, United State...
# 12  (Delhi, Kotwali Tehsil, Central Delhi, Delhi, ...
# 13  (Madison, Dane County, Wisconsin, United State...
# 14             (Guatemala, (15.6356088, -89.8988087))
# 15  (Cheshire, England, United Kingdom, (53.214102...
# 16  (Gold Bridge, Area A (Upper Bridge River Valle...
# 17  (Outside, Poperinge, Ieper, West-Vlaanderen, V...
# 18  (Gate, Northside Drive East, Belair Estates, S...
# 19  (Austin, Travis County, Texas, United States, ...
# 21  (Fennpfuhl, Lichtenberg, Berlin, 10369, Deutsc...
# 23  (G, North Griffin Street, West End Historic Di...
# 26  (Mumbai, Mumbai Suburban, Maharashtra, India, ...
# 27        (United States, (39.7837304, -100.4458825))
# 29  (New York, United States, (40.7127281, -74.006...
# 31  (Deep Woods, Goochland County, Virginia, 23067...
# 33            (Argentina, (-34.9964963, -64.9672817))
# 34        (United States, (39.7837304, -100.4458825))
# 35  (Mar Vista, Los Angeles, Los Angeles County, C...
# 36  (België / Belgique / Belgien, (50.6402809, 4.6...
# 38  (Milwaukee, Milwaukee County, Wisconsin, Unite...
# 39  (1, Vertland, Indianapolis, Indiana, United St...
#
#                                           user_geo
# 0                   (37.1232245, -78.4927721, 0.0)
# 1     (38.145868899999996, -7.36681873826084, 0.0)
# 3                   (43.6534817, -79.3839347, 0.0)
# 4                   (32.0327121, -81.0142786, 0.0)
# 5                   (42.3750997, -71.1056157, 0.0)
# 6   (34.044146350000005, -118.24466336743033, 0.0)
# 7            (39.8755193, 116.38590079894085, 0.0)
# 8          (51.7858531, -0.18807278731855742, 0.0)
# 10                     (46.603354, 1.8883335, 0.0)
# 11                  (28.5421109, -81.3790304, 0.0)
# 12                   (28.6517178, 77.2219388, 0.0)
# 13                   (43.074761, -89.3837613, 0.0)
# 14                  (15.6356088, -89.8988087, 0.0)
# 15           (53.2141028, -2.471770086071205, 0.0)
# 16                 (50.8520571, -122.8404524, 0.0)
# 17            (50.8413263, 2.728553242560873, 0.0)
# 18                   (32.4380721, -81.762407, 0.0)
# 19                  (30.2711286, -97.7436995, 0.0)
# 21                   (52.5287849, 13.4734687, 0.0)
# 23                   (32.781597, -96.8037253, 0.0)
# 26                   (19.0759899, 72.8773928, 0.0)
# 27                 (39.7837304, -100.4458825, 0.0)
# 29                  (40.7127281, -74.0060152, 0.0)
# 31                  (37.8487543, -77.9630524, 0.0)
# 33                 (-34.9964963, -64.9672817, 0.0)
# 34                 (39.7837304, -100.4458825, 0.0)
# 35                 (34.0037605, -118.4391641, 0.0)
# 36                    (50.6402809, 4.6667145, 0.0)
# 38                   (43.0349931, -87.922497, 0.0)
# 39           (39.9162861, -86.05267778244621, 0.0)

# %%
df = df[df.user_location.notnull()]
df.info()

# %%
df.to_csv('random_tweets_loc.csv',index = False,encoding='utf-8')
