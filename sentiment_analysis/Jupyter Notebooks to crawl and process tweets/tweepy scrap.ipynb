# %%
import os
import tweepy as tw
import pandas as pd

# %%
#Add your credentials here
twitter_keys = {
        'consumer_key':        'DY6bpywglf35jBV9RLfe12Rly',
        'consumer_secret':     'YVHXvmWd1dr4HMY7kDPYlqv56wq3xBcokz9T6CzjYyIglJVSBL',
        'access_token_key':    '1331467933214621702-vTWiqTQCghYXjiS1ztfzEI4Rimjtmg',
        'access_token_secret': 'uqb6yVfV5QH3lTgqUtwTgQ4BHKJa1BUZCU6Hy3ucEwLuR'
    }

#Setup access to API
auth = tw.OAuthHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])

api = tw.API(auth,wait_on_rate_limit=True)

# %%
def extract_place(row):
    if row['associated_place']:
        return row['associated_place'].full_name
    else:
        return None
    
def extract_location(row):
    if row['user_location']:
        return row['user_location']
    else:
        return None

# %%
text_query = 'fuck you OR fuck off OR screw you OR dumbass OR fucking bitch OR asshole -has:geo'
max_tweets = 2000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]
 
# Creation of dataframe from tweets_list
# Did not include column names to simplify code 
tweets_df = pd.DataFrame(tweets_list)

# %%
tweets_df = pd.DataFrame(tweets_list)
tweets_df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
                     'user_description','verified','associated_place','retweet_count']
tweets_df.head()
# Out:
#                                                 text   created_date_time  \
# 0  Dawg if yo girl not ready to fuck the skin off... 2021-02-13 17:47:50
# 1  @GhostChannels That dumb bitch and her stupid ... 2021-02-13 17:47:04
# 2  First off fuck your bitch and the clique you c... 2021-02-13 17:43:43
# 3  After I fuck she tryna cuff, bitch you outta l... 2021-02-13 17:42:55
# 4  First off, fuck your bitch and the clique you ... 2021-02-13 17:42:08
#
#               tweet_id         username user_screen_name              user_id  \
# 0  1360646878770188292  PUBLIC ENEMY #1     Stoney2Krazy  1266414898894045184
# 1  1360646687170170888            Devon   thekingkakarot            196440156
# 2  1360645842638688258     Golden Chief         AMFKNole            221114493
# 3  1360645642981412864        Ja〽️ez 🤴🏽   therealjamez21   793533230024646657
# 4  1360645446411034624    Colin Anderle      nderleColin             35918686
#
#                     user_location  \
# 0                     Atlanta, GA
# 1                 Minneapolis, MN
# 2
# 3                     Atlanta, GA
# 4  Isle of Itwhenyoucallmebigpapa
#
#                                     user_description  verified  \
# 0  You Wanna Go to Jail or You Wanna Go Home? | P...     False
# 1  gamer, music fanatic, just some dude. ||\nUse ...     False
# 2  Florida State fan, Esq. Jameis Winston apologi...     False
# 3    Locked outta my old Twitter🤦🏽‍♂️ @theREALjamez_     False
# 4  Currently at the stage of quarantine where my ...     False
#
#   associated_place  retweet_count
# 0             None              0
# 1             None              0
# 2             None              0
# 3             None              0
# 4             None              0

# %%
# 14  1360638871617290244  🏴‍☠️✝️ kotetsuran✝️ 🏴‍☠️ | full time getter stan
# 15  1360638703824211970                                              lila
# 16  1360638623398260736                            xX| Marci (it/its) |Xx
# 17  1360638550174277633                                           marlene
# 18  1360638486114521093                                 Whathappenedtous?
# 19  1360638472965427201                                       Jason Young
# 20  1360637788627034114                                         The Gaben
# 21  1360637224207978498                                     Sewer Monster
# 22  1360637059153551367                                           Cricket
# 23  1360634534501482502                               fatma paining READ📌
# 24  1360634435268452355                                              Miah
# 25  1360634059739828225                                              June
# 26  1360632350741299204                                              Lopz
# 27  1360632133828677636                                             sux 📌
# 28  1360632066216316929                                       KEL-LFC 💫🇦🇺
# 29  1360629641900400642                                            mays 💿
#
#    user_screen_name              user_id                   user_location  \
# 0      Stoney2Krazy  1266414898894045184                     Atlanta, GA
# 1    thekingkakarot            196440156                 Minneapolis, MN
# 2          AMFKNole            221114493                            None
# 3    therealjamez21   793533230024646657                     Atlanta, GA
# 4       nderleColin             35918686  Isle of Itwhenyoucallmebigpapa
# 5         notapar72           1314873150                            None
# 6       nm_thefirst  1245740186438336513                 London, England
# 7           mdigiov             44141802                            None
# 8        DomRapture             33080246                  Cincinnati, OH
# 9      ColorMeBray_           2323955642                   TamiyaMommy👧🏾
# 10  Iambeautiful_95            923875339                            None
# 11  JimmerThatisAll            468852567               Corktown. Canada.
# 12   ThatMoustachio           2833623721                       The place
# 13    _OrangeArtist  1135925912652959744             it/cave/nya/they/he
# 14      godzillacc5           2464438427                      Costa Rica
# 15        translila  1297629456660680707            someplace in england
# 16       hellamarci  1194437829264171008                         WA, Aus
# 17        devdroses  1097647934261391370                       22 | 🇺🇸🇲🇽
# 18  Whathap44307552  1346000915497553921                            None
# 19  REALJasonDYoung   837488199937085444                     Phoenix, AZ
# 20    TheGabenTwitt   963073815701057536   Texas | Male | The Gaben#6018
# 21  kreminthesewers           2539943763                       The Sewer
# 22      CoastalCndn            316245912                            None
# 23     ThatTomiChan  1141438342187405312         She/her MINOR‼️/ 6yo!!!
# 24   official_qmiah           3241331848                            None
# 25        JUNE24452  1316730432440991749                            None
# 26           LOPZxx           1656032431                            None
# 27         minnoise  1211425706539773952              she/her, 17, black
# 28          Kelz081             89187364                       Melbourne
# 29  TheRedOneSoScar  1143152196223197185                     16, she/her
#
#                                      user_description  verified  \
# 0   You Wanna Go to Jail or You Wanna Go Home? | P...     False
# 1   gamer, music fanatic, just some dude. ||\nUse ...     False
# 2   Florida State fan, Esq. Jameis Winston apologi...     False
# 3     Locked outta my old Twitter🤦🏽‍♂️ @theREALjamez_     False
# 4   Currently at the stage of quarantine where my ...     False
# 5                                                         False
# 6   Education haunts me, just like Man Utd fans 🇹🇿...     False
# 7                                                         False
# 8   Level 30 Fat Human|Pro Day Dreamer|Gamer|Redle...     False
# 9   S C O R P I O ♏ | 📈 g e m i n i | 🌙 A q u a r ...     False
# 10                                  IG📸 verybellagirl     False
# 11  From the 12 winded sky. Profile pic '72. Remem...     False
# 12  Host of Mr. Moustachio's Great Show of Excelle...     False
# 13  how did i get here |\n#undertaletwt LET ME IN ...     False
# 14                              Believe in the getter     False
# 15  hey there!\ni'm a trans girl from the uk who l...     False
# 16  Hiya, I'm Marci !!~ 💙💙 | it/its, she/they| pol...     False
# 17                                     hewwo. she/her     False
# 18                                                        False
# 19                                                        False
# 20  Smash, FF, KH, DR, Xenoblade, GMod, TF2 | @The...     False
# 21                                                        False
# 22  Atheist 🇨🇦 #AdoptDontShop I was a much nicer p...     False
# 23  DO NOT HMU I DONT LIKE PEOPLE🙏🙏🙏/hj || @bnhami...     False
# 24  ME-AH• Artist • NYC hairstylist • IG: @officia...     False
# 25                                                        False
# 26                                          IG: lopz_     False
# 27                                              😸😿😺😾😹     False
# 28           @LFC @CarltonFC @Lakers #FreePalestine🇵🇸     False
# 29  🐱❤🐰\n                                         ...     False
#
#    associated_place  retweet_count
# 0              None              0
# 1              None              0
# 2              None              0
# 3              None              0
# 4              None              0
# 5              None              0
# 6              None              0
# 7              None              0
# 8              None              0
# 9              None              0
# 10             None              3
# 11             None              2
# 12             None              0
# 13             None              0
# 14             None             11
# 15             None            848
# 16             None            848
# 17             None              0
# 18             None              0
# 19             None              0
# 20             None             11
# 21             None             11
# 22             None              0
# 23             None              0
# 24             None              0
# 25             None             11
# 26             None              0
# 27             None              0
# 28             None              0
# 29             None              2

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 2000 non-null object
# created_date_time    2000 non-null datetime64[ns]
# tweet_id             2000 non-null object
# username             2000 non-null object
# user_screen_name     2000 non-null object
# user_id              2000 non-null object
# user_location        1389 non-null object
# user_description     2000 non-null object
# verified             2000 non-null bool
# associated_place     25 non-null object
# retweet_count        2000 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 158.3+ KB

# %%
tweets_df = tweets_df[tweets_df.user_location.notnull()]
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1389 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 1389 non-null object
# created_date_time    1389 non-null datetime64[ns]
# tweet_id             1389 non-null object
# username             1389 non-null object
# user_screen_name     1389 non-null object
# user_id              1389 non-null object
# user_location        1389 non-null object
# user_description     1389 non-null object
# verified             1389 non-null bool
# associated_place     23 non-null object
# retweet_count        1389 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 120.7+ KB

# %%
text_query = 'go to hell OR go and die OR hope you die -has:geo'
max_tweets = 2000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]
 
# Creation of dataframe from tweets_list
# Did not include column names to simplify code 
df = pd.DataFrame(tweets_list)

# %%
df = pd.DataFrame(tweets_list)
df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
              'user_description','verified','associated_place','retweet_count']
df['associated_place'] = df.apply(extract_place,axis=1)
df['user_location'] = df.apply(extract_location,axis=1)
tweets_df = pd.concat([tweets_df, df])
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3389 entries, 0 to 1999
# Data columns (total 11 columns):
# text                
# 16  1360638623398260736                            xX| Marci (it/its) |Xx
# 17  1360638550174277633                                           marlene
# 19  1360638472965427201                                       Jason Young
# 20  1360637788627034114                                         The Gaben
# 21  1360637224207978498                                     Sewer Monster
# 23  1360634534501482502                               fatma paining READ📌
# 27  1360632133828677636                                             sux 📌
# 28  1360632066216316929                                       KEL-LFC 💫🇦🇺
# 29  1360629641900400642                                            mays 💿
# 30  1360627318331478018                                        Max Julien
# 31  1360625943585435654                                       XxKoz zoOxX
# 33  1360625018804273155                                     Alan Horsnell
# 34  1360624984511627267                               floptina bestie ☁︎︎
# 35  1360624446776737793                                      Jac Thiebeau
# 36  1360621278617604099                                           Kelly K
# 42  1360615438082838529                                        Dr. Kaiser
# 43  1360615302950760451                                 Anee (like limit)
# 45  1360612680474767365                                          ~My$tic~
#
#    user_screen_name              user_id                   user_location  \
# 0      Stoney2Krazy  1266414898894045184                     Atlanta, GA
# 1    thekingkakarot            196440156                 Minneapolis, MN
# 3    therealjamez21   793533230024646657                     Atlanta, GA
# 4       nderleColin             35918686  Isle of Itwhenyoucallmebigpapa
# 6       nm_thefirst  1245740186438336513                 London, England
# 8        DomRapture             33080246                  Cincinnati, OH
# 9      ColorMeBray_           2323955642                   TamiyaMommy👧🏾
# 11  JimmerThatisAll            468852567               Corktown. Canada.
# 12   ThatMoustachio           2833623721                       The place
# 13    _OrangeArtist  1135925912652959744             it/cave/nya/they/he
# 14      godzillacc5           2464438427                      Costa Rica
# 15        translila  1297629456660680707            someplace in england
# 16       hellamarci  1194437829264171008                         WA, Aus
# 17        devdroses  1097647934261391370                       22 | 🇺🇸🇲🇽
# 19  REALJasonDYoung   837488199937085444                     Phoenix, AZ
# 20    TheGabenTwitt   963073815701057536   Texas | Male | The Gaben#6018
# 21  kreminthesewers           2539943763                       The Sewer
# 23     ThatTomiChan  1141438342187405312         She/her MINOR‼️/ 6yo!!!
# 27         minnoise  1211425706539773952              she/her, 17, black
# 28          Kelz081             89187364                       Melbourne
# 29  TheRedOneSoScar  1143152196223197185                     16, she/her
# 30      K_Maynard13             43591265                       MSY 🛫 LAX
# 31    ShadowKozlest   926923717749432322        Any Pronouns, Gynesexual
# 33  papa_aint_salty   726129596400304132                   Nashville, TN
# 34  averieadoresyou  1007736018467020801                        she/her
# 35      Cybershroom           3855295587                       Ohio, USA
# 36   KellyKPMArtist            453624069                    St Louis, MO
# 42     TDevilkaiser  1314322038090326018                         Tokyo-3
# 43         BoneJoor  1333991451294912512                   I TOLD YOU SO
# 45      mitchy_page           1881669240                          Texass
#
#                                      user_description  verified  \
# 0   You Wanna Go to Jail or You Wanna Go Home? | P...     False
# 1   gamer, music fanatic, just some dude. ||\nUse ...     False
# 3     Locked outta my old Twitter🤦🏽‍♂️ @theREALjamez_     False
# 4   Currently at the stage of quarantine where my ...     False
# 6   Education haunts me, just like Man Utd fans 🇹🇿...     False
# 8   Level 30 Fat Human|Pro Day Dreamer|Gamer|Redle...     False
# 9   S C O R P I O ♏ | 📈 g e m i n i | 🌙 A q u a r ...     False
# 11  From the 12 winded sky. Profile pic '72. Remem...     False
# 12  Host of Mr. Moustachio's Great Show of Excelle...     False
# 13  how did i get here |\n#undertaletwt LET ME IN ...     False
# 14                              Believe in the getter     False
# 15  hey there!\ni'm a trans girl from the uk who l...     False
# 16  Hiya, I'm Marci !!~ 💙💙 | it/its, she/they| pol...     False
# 17                                     hewwo. she/her     False
# 19                                                        False
# 20  Smash, FF, KH, DR, Xenoblade, GMod, TF2 | @The...     False
# 21                                                        False
# 23  DO NOT HMU I DONT LIKE PEOPLE🙏🙏🙏/hj || @bnhami...     False
# 27                                              😸😿😺😾😹     False
# 28           @LFC @CarltonFC @Lakers #FreePalestine🇵🇸     False
# 29  🐱❤🐰\n                                         ...     False
# 30                   From The Southside With Love, ✌🏽     False
# 31  The names Koz, professional lurker, Pro fictio...     False
# 33  Let the rest of your days be spent as one who ...     False
# 34  #TINA: “The ass in massive” All I do is eat an...     False
# 35                      I wanna grill and make Vidya.     False
# 36  #blacklivesmatter liberal in a family of conse...     False
# 42  Immortal god machine sets the world free • Kai...     False
# 43                                         Cyrus#9499     False
# 45      🎹🎸🎼🌉 ~My$tic~ Listen and i'll play you a tune     False
#
#    associated_place  retweet_count
# 0              None              0
# 1              None              0
# 3              None              0
# 4              None              0
# 6              None              0
# 8              None              0
# 9              None              0
# 11             None              2
# 12             None              0
# 13             None              0
# 14             None             11
# 15             None            848
# 16             None            848
# 17             None              0
# 19             None              0
# 20             None             11
# 21             None             11
# 23             None              0
# 27             None              0
# 28             None              0
# 29             None              2
# 30  New Orleans, LA              0
# 31             None             11
# 33             None              0
# 34             None              2
# 35             None             11
# 36             None              0
# 42             None             11
# 43             None             11
# 45             None              0

# %%
text_query = 'whore OR slut -has:geo'
max_tweets = 2000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]

# %%
df = pd.DataFrame(tweets_list)
df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
              'user_description','verified','associated_place','retweet_count']
df['associated_place'] = df.apply(extract_place,axis=1)
df['user_location'] = df.apply(extract_location,axis=1)
tweets_df = pd.concat([tweets_df, df])
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5389 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 5389 non-null object
# created_date_time    5389 non-null datetime64[ns]
# tweet_id             5389 non-null object
# username             5389 non-null object
# user_screen_name     5389 non-null object
# user_id              5389 non-null object
# user_location        4104 non-null object
# user_description     5389 non-null object
# verified             5389 non-null bool
# associated_place     48 non-null object
# retweet_count        5389 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 468.4+ KB

# %%
text_query = 'you loser OR you are a loser OR what a loser OR fucking loser -has:geo'
max_tweets = 2000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]

# %%
df = pd.DataFrame(tweets_list)
df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
              'user_description','verified','associated_place','retweet_count']
df['associated_place'] = df.apply(extract_place,axis=1)
df['user_location'] = df.apply(extract_location,axis=1)
tweets_df = pd.concat([tweets_df, df])
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7389 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 7389 non-null object
# created_date_time    7389 non-null datetime64[ns]
# tweet_id             7389 non-null object
# username             7389 non-null object
# user_screen_name     7389 non-null object
# user_id              7389 non-null object
# user_location        5451 non-null object
# user_description     7389 non-null object
# verified             7389 non-null bool
# associated_place     63 non-null object
# retweet_count        7389 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 642.2+ KB

# %%
tweets_df = tweets_df[tweets_df.user_location.notnull()]
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5451 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 5451 non-null object
# created_date_time    5451 non-null datetime64[ns]
# tweet_id             5451 non-null object
# username             5451 non-null object
# user_screen_name     5451 non-null object
# user_id              5451 non-null object
# user_location        5451 non-null object
# user_description     5451 non-null object
# verified             5451 non-null bool
# associated_place     56 non-null object
# retweet_count        5451 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 473.8+ KB

# %%
text_query = 'retard OR stupid OR dumb -has:geo'
max_tweets = 2000
 
# Creation of query method using parameters
tweets = tw.Cursor(api.search,q=text_query,lang="en").items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, 
                tweet.created_at, 
                tweet.id_str, 
                tweet.user.name, 
                tweet.user.screen_name, 
                tweet.user.id_str, 
                tweet.user.location, 
                tweet.user.description, 
                tweet.user.verified, 
                tweet.place,
                tweet.retweet_count] for tweet in tweets]

# %%
df = pd.DataFrame(tweets_list)
df.columns = ['text', 'created_date_time','tweet_id','username','user_screen_name','user_id','user_location',
              'user_description','verified','associated_place','retweet_count']
df['associated_place'] = df.apply(extract_place,axis=1)
df['user_location'] = df.apply(extract_location,axis=1)
tweets_df = pd.concat([tweets_df, df])
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7451 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 7451 non-null object
# created_date_time    7451 non-null datetime64[ns]
# tweet_id             7451 non-null object
# username             7451 non-null object
# user_screen_name     7451 non-null object
# user_id              7451 non-null object
# user_location        6776 non-null object
# user_description     7451 non-null object
# verified             7451 non-null bool
# associated_place     83 non-null object
# retweet_count        7451 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 647.6+ KB

# %%
tweets_df = tweets_df[tweets_df.user_location.notnull()]
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6776 entries, 0 to 1999
# Data columns (total 11 columns):
# text                 6776 non-null object
# created_date_time    6776 non-null datetime64[ns]
# tweet_id             6776 non-null object
# username             6776 non-null object
# user_screen_name     6776 non-null object
# user_id              6776 non-null object
# user_location        6776 non-null object
# user_description     6776 non-null object
# verified             6776 non-null bool
# associated_place     77 non-null object
# retweet_count        6776 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(8)
# memory usage: 588.9+ KB

# %%
tweets_df = tweets_df.sample(frac=1).reset_index(drop=True)

# %%
tweets_df.to_csv('negative_tweets.csv',index = False)
